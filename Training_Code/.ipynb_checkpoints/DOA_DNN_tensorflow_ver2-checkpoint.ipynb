# %%
# Importing the libraries
import numpy as np 
import pandas as pd
import glob, os
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.0.1

# %%
## TRAINING DATA

path = './'                     # use your path
all_files = glob.glob(os.path.join(path, "data*"))     # advisable to use os.path.join as this makes concatenation OS independent

dataset = pd.DataFrame()
list_ = []
cnt=0
for file_ in all_files:
    cnt=cnt+1
    df = pd.read_csv(file_,index_col=None, header=0)# nrows=999999
    print(cnt,file_,'Size:', df.shape)
    list_.append(df.as_matrix())

comb_np_array = np.vstack(list_)
dataset = pd.DataFrame(comb_np_array)
# Out:
# (1, './data_Sim_DOA_Room1_0_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (2, './data_Sim_DOA_Room1_100_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (3, './data_Sim_DOA_Room1_120_degree_MP_dnn.csv', 'Size:', (44998, 14))
# /usr/lib/python2.7/site-packages/ipykernel_launcher.py:13: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   del sys.path[0]
# (4, './data_Sim_DOA_Room1_140_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (5, './data_Sim_DOA_Room1_160_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (6, './data_Sim_DOA_Room1_180_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (7, './data_Sim_DOA_Room1_20_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (8, './data_Sim_DOA_Room1_40_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (9, './data_Sim_DOA_Room1_60_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (10, './data_Sim_DOA_Room1_80_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (11, './data_Sim_DOA_Room2_0_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (12, './data_Sim_DOA_Room2_100_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (13, './data_Sim_DOA_Room2_120_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (14, './data_Sim_DOA_Room2_140_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (15, './data_Sim_DOA_Room2_160_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (16, './data_Sim_DOA_Room2_180_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (17, './data_Sim_DOA_Room2_20_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (18, './data_Sim_DOA_Room2_40_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (19, './data_Sim_DOA_Room2_60_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (20, './data_Sim_DOA_Room2_80_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (21, './data_Sim_DOA_Room3_0_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (22, './data_Sim_DOA_Room3_100_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (23, './data_Sim_DOA_Room3_120_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (24, './data_Sim_DOA_Room3_140_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (25, './data_Sim_DOA_Room3_160_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (26, './data_Sim_DOA_Room3_180_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (27, './data_Sim_DOA_Room3_20_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (28, './data_Sim_DOA_Room3_40_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (29, './data_Sim_DOA_Room3_60_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (30, './data_Sim_DOA_Room3_80_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (31, './data_Sim_DOA_Room4_0_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (32, './data_Sim_DOA_Room4_100_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (33, './data_Sim_DOA_Room4_120_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (34, './data_Sim_DOA_Room4_140_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (35, './data_Sim_DOA_Room4_160_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (36, './data_Sim_DOA_Room4_180_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (37, './data_Sim_DOA_Room4_20_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (38, './data_Sim_DOA_Room4_40_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (39, './data_Sim_DOA_Room4_60_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (40, './data_Sim_DOA_Room4_80_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (41, './data_Sim_DOA_Room5_0_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (42, './data_Sim_DOA_Room5_100_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (43, './data_Sim_DOA_Room5_120_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (44, './data_Sim_DOA_Room5_140_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (45, './data_Sim_DOA_Room5_160_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (46, './data_Sim_DOA_Room5_180_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (47, './data_Sim_DOA_Room5_20_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (48, './data_Sim_DOA_Room5_40_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (49, './data_Sim_DOA_Room5_60_degree_MP_dnn.csv', 'Size:', (44998, 14))
# (50, './data_Sim_DOA_Room5_80_degree_MP_dnn.csv', 'Size:', (44998, 14))

# %%
print('Size:', dataset.shape)
# Out:
# ('Size:', (2249900, 14))

# %%
del comb_np_array
del df
del list_

# %%
nf=1 # number of frame for each image

(len_data,b)=(dataset.shape)

image_row=nf*2
image_col=(b-1)/4
batch_size=40
len_x = int(len_data/(nf*batch_size*10))*batch_size*10

# %%
print(len_data)
# Out:
# 2249900

# %%
#(len_data,b)=(dataset.shape)
inputdim=b-1;


X = dataset.iloc[0:nf*len_x, 0:inputdim].values
y  = dataset.iloc[0:nf*len_x, inputdim].values
#X_train = dataset.iloc[0:len_train, 0:inputdim].values
#y_train  = dataset.iloc[0:len_train, inputdim].values
#X_test = dataset.iloc[len_train:len_train+len_test, 0:inputdim].values
#y_test  = dataset.iloc[len_train:len_train+len_test, inputdim].values
print(y.shape)
# Out:
# (2249600,)

# %%
ake_y  = y.reshape(len_x,nf)
ake_y=ake_y[:,0]
ake_y=np.divide(ake_y, 20).astype(int)
two_ch_input_x=X.reshape(len_x, nf *inputdim)
#print('len_train:', len_x)

# %%
del dataset
del X
del y

# %%
idx = np.random.permutation(len_x)
two_ch_input_x,ake_y = two_ch_input_x[idx], ake_y[idx]

# %%
len_train=int(len_x*0.9)
len_train=int(len_train/nf)*nf


len_test=int(len_x*0.1)
len_test=int(len_test/nf)*nf

print('len_train:', len_train)
print('len_test:', len_test)
# Out:
# ('len_train:', 2024640)
# ('len_test:', 224960)

# %%
two_ch_input_training = two_ch_input_x[0:len_train, :]
ake_y_train  = ake_y[0:len_train, ]
two_ch_input_test = two_ch_input_x[len_train:len_x, :]
ake_y_test  = ake_y[len_train:len_x, ]

# %%
def one_hot_encode(idx, vals=10):
    '''
    For use to one-hot encode the 10- possible labels
    '''
    len_idx=len(idx)
    out = np.zeros((len_idx, vals))
    for i in range(len_idx):
        out[i,idx[i]] = 1
        
    return out

# %%
two_ch_y_training = one_hot_encode(ake_y,10) 
two_ch_y_test = one_hot_encode(ake_y_test,10)

# %%
size_test=  int(len_test/batch_size)

print(size_test)

size_train=  int(len_train/batch_size)
print(size_train)
# Out:
# 5624
# 50616

# %%
# Data helper
class DataHelper():
    
    def __init__(self):
        self.i = 0
        self.k = 0
        
        #self.all_train_batches = [data_batch1,data_batch2,data_batch3,data_batch4,data_batch5]
        #self.test_batch = [test_batch]
        
        self.training_data = None
        self.training_labels = None
        
        self.test_data = None
        self.test_labels = None
    
    def set_up_data(self,two_ch_input_training,y_training,two_ch_input_test,y_test):
        
        print("Setting Up Training Data and Labels")
        
        self.training_data= two_ch_input_training 
        train_len = len(self.training_data)
        
        self.training_labels = y_training
        
        print("Setting Up Test Images and Labels")
        
        self.test_data = two_ch_input_test
        test_len = len(self.test_data)
        
        self.test_labels = y_test

        
    def next_batch(self, batch_size):
        x = self.training_data[self.i:self.i+batch_size]
        y = self.training_labels[self.i:self.i+batch_size]
        self.i = (self.i + batch_size) % len(self.training_data)
        return x, y
    
    def next_batch_test(self, batch_size):
        x_test = self.test_data[self.k:self.k+batch_size]
        y_test = self.test_labels[self.k:self.k+batch_size]
        self.k = (self.k + batch_size) % len(self.test_data)
        return x_test, y_test

# %%
dh = DataHelper()
dh.set_up_data(two_ch_input_training,two_ch_y_training,two_ch_input_test,two_ch_y_test)
# Out:
# Setting Up Training Data and Labels
# Setting Up Test Images and Labels

# %%
del two_ch_input_x
del two_ch_input_training
del two_ch_y_training
del two_ch_input_test
del two_ch_y_test
del ake_y
del ake_y_test
del idx

# %%
##### CREATING MODEL ########



with tf.name_scope("inputs"):
    xx = tf.placeholder(tf.float32,[None,nf*inputdim],"x-input")
    #x_image = tf.reshape(x, [-1, 2,image_row, image_col], name="x-image")  
    #x_image =tf.transpose(x_image, perm=[0,2,3,1],name="x-imaget")  
    y_true = tf.placeholder(tf.float32,[None,10], "y-true")
    
#with tf.name_scope("hyperparameters"):
    #hold_prob = tf.constant(0.1, name='hold_prob')
    #hold_prob = tf.placeholder(tf.float32, name='hold_prob')
    


## HELPER FUNCTIONS ##

def init_weights(shape):
    init_random_dist = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(init_random_dist)

def init_bias(shape):
    init_bias_vals = tf.constant(0.1, shape=shape)
    return tf.Variable(init_bias_vals)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2by2(x):
    return tf.nn.max_pool(x, ksize=[1, 1, 1, 1],
                          strides=[1, 2, 2, 1], padding='SAME')

def convolutional_layer(input_x, shape):
    W = init_weights(shape)
    b = init_bias([shape[3]])
    return tf.nn.relu(conv2d(input_x, W) + b)

def normal_full_layer(input_layer, size):
    input_size = int(input_layer.get_shape()[1])
    W = init_weights([input_size, size])
    b = init_bias([size])
    return tf.matmul(input_layer, W) + b
def lstm_cell():
    return tf.contrib.rnn.BasicRNNCell(num_units=num_hidden_lstm, activation=tf.nn.relu)

# %%
## CREATE LAYERS ## 
    

full_layer_one = tf.nn.sigmoid(normal_full_layer(xx,512))

#full_one_dropout = tf.nn.dropout(full_layer_one,keep_prob=0.2)

full_layer_two = tf.nn.sigmoid(normal_full_layer(full_layer_one,512))
#full_two_dropout = tf.nn.dropout(full_layer_two,keep_prob=0.2)

full_layer_three = tf.nn.sigmoid(normal_full_layer(full_layer_two,512))
#full_three_dropout = tf.nn.dropout(full_layer_three,keep_prob=0.5)
full_layer_four = tf.nn.relu(normal_full_layer(full_layer_three,512))

#full_layer_five = tf.nn.relu(normal_full_layer(full_layer_four,512))

#full_layer_six = tf.nn.relu(normal_full_layer(full_layer_five,512))



y_pred = (normal_full_layer(full_layer_four,10))
y_pred = tf.identity(y_pred,'output_t');

## LOSS FUNCTION ##

cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true,logits=y_pred))

## OPTIMIZER ##
optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
train = optimizer.minimize(cross_entropy)

init = tf.global_variables_initializer()

# %%
epochnumber=150
checkpoint_dir = "models/"
tf.gfile.MakeDirs(checkpoint_dir)

with tf.Session() as sess:
    
    saver = tf.train.Saver()
    # tf.train.write_graph(sess.graph_def,
    #                     FLAGS.checkpoint_dir,
    #                    "graph.pbtxt",
    #                    True)
   
    sess.run(tf.global_variables_initializer())
    for epoch in range (epochnumber):
        train_batch_count = 0 
        train_batch_acc_total = 0
        for i in range(size_train):
            batch = dh.next_batch(batch_size)
            #print(batch[0].shape)
            sess.run(train, feed_dict={'inputs/x-input:0': batch[0], 'inputs/y-true:0': batch[1]})# hold_prob: 0.5
           


            if i%1000 == 0:
                print('Currently on training step {}'.format(i))


            # PRINT OUT A MESSAGE EVERY 100 STEPS
            if i%(size_train-1) == 0 and i!=0:
                print('Currently on step {} for Testing'.format(i))
                
                test_batch_acc_total = 0
                test_batch_count = 0
                matches = tf.equal(tf.argmax(y_pred,1),tf.argmax(y_true,1))
                acc = tf.reduce_mean(tf.cast(matches,tf.float32))
                

                for k in range (size_test):
                    #dh.i=0
                    batch_test = dh.next_batch_test(batch_size)
                    test_batch_acc_total += sess.run(acc,feed_dict={'inputs/x-input:0':batch_test[0],'inputs/y-true:0':batch_test[1]}) #,hold_prob:1.0
                    test_batch_count += 1
                    train_batch_acc_total += sess.run(acc,feed_dict={'inputs/x-input:0':batch[0],'inputs/y-true:0':batch[1]}) #,hold_prob:1.0
                    train_batch_count += 1


                    if k%1000 == 0:
                        print('Currently on testing step {}'.format(k))

                print('Epoch: {}'.format(epoch))
                print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))
                print('Training Accuracy: {}\n'.format(train_batch_acc_total/train_batch_count))
                tf.train.write_graph(sess.graph_def, checkpoint_dir, 'graph_DOA_2.pbtxt', as_text=True)
#    tf.train.Saver(tf.trainable_variables()).save(sess, 'Babble_0_Real_Imag_Dr40/my-model-chkpt')
                tf.gfile.MakeDirs( checkpoint_dir + str(epoch))
                checkpoint_file = os.path.join(  checkpoint_dir + str(epoch), "model")
                saver.save(sess, checkpoint_file)
                print("**** SAVED MODEL ****")      
                print("**** COMPLETED ALL THE EPOCHS ****")
                #dh.i=0
                #dh.k=0





                #print('Accuracy is:')
                # Test the Train Model
                #matches = tf.equal(tf.argmax(y_pred,1),tf.argmax(y_true,1))

                #print (sess.run(y_pred))
    #            print (sess.run(y_true))
                #acc = tf.reduce_mean(tf.cast(matches,tf.float32))
               # print(sess.run(acc,feed_dict={x:dh.test_data,y_true:dh.test_labels,hold_prob:1.0}))
    #            print(sess.run(tf.argmax(y_pred,1), feed_dict={x:dh.test_data, y_true:dh.test_labels,hold_prob:1.0  }))
    #            print(sess.run(tf.argmax(y_true,1), feed_dict={x:dh.test_data, y_true:dh.test_labels,hold_prob:1.0  }))
                #print('\n')
    #            print(sess.run(acc, feed_dict={x: batch[0], y_true: batch[1], hold_prob: 1.0}))
    #            print(sess.run(tf.argmax(y_pred,1), feed_dict={x:batch[0], y_true:batch[1],hold_prob:1.0  }))
    #            print(sess.run(tf.argmax(y_true,1), feed_dict={x:batch[0], y_true:batch[1],hold_prob:1.0  }))

    #            print(dh.training_data.shape)
    #            print(batch[1].shape)
# Out:
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 0
# Testing Accuracy: 0.256334465377
#
# Training Accuracy: 0.324999988079
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 1
# Testing Accuracy: 0.265229380381
#
# Training Accuracy: 0.375
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 2
# Testing Accuracy: 0.270532545445
#
# Training Accuracy: 0.450000017881
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 3
# Testing Accuracy: 0.302191507662
#
# Training Accuracy: 0.424999982119
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 4
# Testing Accuracy: 0.318501073879
#
# Training Accuracy: 0.34999999404
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 5
# Testing Accuracy: 0.332912525126
#
# Training Accuracy: 0.34999999404
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 6
# Testing Accuracy: 0.35774805179
#
# Training Accuracy: 0.325000017881
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 7
# Testing Accuracy: 0.354538592135
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 8
# Testing Accuracy: 0.361433151307
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 9
# Testing Accuracy: 0.368069886671
#
# Training Accuracy: 0.325000017881
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 10
# Testing Accuracy: 0.371692753263
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 11
# Testing Accuracy: 0.380796594042
#
# Training Accuracy: 0.47499999404
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 12
# Testing Accuracy: 0.384094958329
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 13
# Testing Accuracy: 0.384926217082
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 14
# Testing Accuracy: 0.404120739971
#
# Training Accuracy: 0.34999999404
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 15
# Testing Accuracy: 0.408637098764
#
# Training Accuracy: 0.450000017881
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 16
# Testing Accuracy: 0.411535391457
#
# Training Accuracy: 0.350000023842
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 17
# Testing Accuracy: 0.414580377023
#
# Training Accuracy: 0.40000000596
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 18
# Testing Accuracy: 0.414238094157
#
# Training Accuracy: 0.40000000596
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 19
# Testing Accuracy: 0.416291792815
#
# Training Accuracy: 0.34999999404
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 20
# Testing Accuracy: 0.421750540889
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 21
# Testing Accuracy: 0.429960889167
#
# Training Accuracy: 0.450000017881
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 22
# Testing Accuracy: 0.429436351442
#
# Training Accuracy: 0.375
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# ...
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 142
# Testing Accuracy: 0.478760676088
#
# Training Accuracy: 0.5
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 143
# Testing Accuracy: 0.474408791487
#
# Training Accuracy: 0.425000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 144
# Testing Accuracy: 0.474835534226
#
# Training Accuracy: 0.5
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 145
# Testing Accuracy: 0.467776501469
#
# Training Accuracy: 0.424999982119
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 146
# Testing Accuracy: 0.472310640933
#
# Training Accuracy: 0.550000011921
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 147
# Testing Accuracy: 0.477724936601
#
# Training Accuracy: 0.5
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 148
# Testing Accuracy: 0.467189730393
#
# Training Accuracy: 0.5
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
# Currently on training step 0
# Currently on training step 1000
# Currently on training step 2000
# Currently on training step 3000
# Currently on training step 4000
# Currently on training step 5000
# Currently on training step 6000
# Currently on training step 7000
# Currently on training step 8000
# Currently on training step 9000
# Currently on training step 10000
# Currently on training step 11000
# Currently on training step 12000
# Currently on training step 13000
# Currently on training step 14000
# Currently on training step 15000
# Currently on training step 16000
# Currently on training step 17000
# Currently on training step 18000
# Currently on training step 19000
# Currently on training step 20000
# Currently on training step 21000
# Currently on training step 22000
# Currently on training step 23000
# Currently on training step 24000
# Currently on training step 25000
# Currently on training step 26000
# Currently on training step 27000
# Currently on training step 28000
# Currently on training step 29000
# Currently on training step 30000
# Currently on training step 31000
# Currently on training step 32000
# Currently on training step 33000
# Currently on training step 34000
# Currently on training step 35000
# Currently on training step 36000
# Currently on training step 37000
# Currently on training step 38000
# Currently on training step 39000
# Currently on training step 40000
# Currently on training step 41000
# Currently on training step 42000
# Currently on training step 43000
# Currently on training step 44000
# Currently on training step 45000
# Currently on training step 46000
# Currently on training step 47000
# Currently on training step 48000
# Currently on training step 49000
# Currently on training step 50000
# Currently on step 50615 for Testing
# Currently on testing step 0
# Currently on testing step 1000
# Currently on testing step 2000
# Currently on testing step 3000
# Currently on testing step 4000
# Currently on testing step 5000
# Epoch: 149
# Testing Accuracy: 0.474897767214
#
# Training Accuracy: 0.40000000596
#
# **** SAVED MODEL ****
# **** COMPLETED ALL THE EPOCHS ****
